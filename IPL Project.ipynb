# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
ipl = pd.read_csv("S:\PROJECT dataset\IPL Matches 2008-2020.csv")

# %%
ipl
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
ipl.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
ipl.shape
# Out:
# (816, 17)

# %%
ipl.dtypes
# Out:
# id                   int64
# city                object
# date                object
# player_of_match     object
# venue               object
# neutral_venue        int64
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# winner              object
# result              object
# result_margin      float64
# eliminator          object
# method              object
# umpire1             object
# umpire2             object
# dtype: object

# %%
ipl.count()
# Out:
# id                 816
# city               803
# date               816
# player_of_match    812
# venue              816
# neutral_venue      816
# team1              816
# team2              816
# toss_winner        816
# toss_decision      816
# winner             812
# result             812
# result_margin      799
# eliminator         812
# method              19
# umpire1            816
# umpire2            816
# dtype: int64

# %%
ipl["player_of_match"].value_counts()[:20]
# Out:
# AB de Villiers    23
# CH Gayle          22
# RG Sharma         18
# MS Dhoni          17
# DA Warner         17
# YK Pathan         16
# SR Watson         16
# SK Raina          14
# G Gambhir         13
# V Kohli           13
# MEK Hussey        12
# AM Rahane         12
# V Sehwag          11
# KA Pollard        11
# DR Smith          11
# A Mishra          11
# AD Russell        11
# JH Kallis         10
# AT Rayudu         10
# SP Narine          9
# Name: player_of_match, dtype: int64

# %%
ipl["player_of_match"].value_counts()
# Out:
# AB de Villiers    23
# CH Gayle          22
# RG Sharma         18
# MS Dhoni          17
# DA Warner         17
#                   ..
# B Stanlake         1
# DL Vettori         1
# SB Jakati          1
# GJ Bailey          1
# BCJ Cutting        1
# Name: player_of_match, Length: 233, dtype: int64

# %%
ipl["player_of_match"].value_counts().head()
# Out:
# AB de Villiers    23
# CH Gayle          22
# RG Sharma         18
# MS Dhoni          17
# DA Warner         17
# Name: player_of_match, dtype: int64

# %%
list(ipl["player_of_match"].value_counts().head().keys())
# Out:
# ['AB de Villiers', 'CH Gayle', 'RG Sharma', 'MS Dhoni', 'DA Warner']

# %%
plt.figure(figsize=(8,5))
plt.bar(list(ipl["player_of_match"].value_counts().head().keys()),ipl["player_of_match"].value_counts().head(),color=('red','blue','green','yellow','pink'))
plt.show()

# %%
ipl.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
ipl["result"].value_counts()
# Out:
# wickets    435
# runs       364
# tie         13
# Name: result, dtype: int64

# %%
bat_first = ipl[ipl["result"] == "runs"]

# %%
bat_first.head()
# Out:
#         id        city        date player_of_match  \
# 0   335982   Bangalore  2008-04-18     BB McCullum
# 1   335983  Chandigarh  2008-04-19      MEK Hussey
# 7   335989     Chennai  2008-04-23       ML Hayden
# 9   335991  Chandigarh  2008-04-25   KC Sangakkara
# 14  335996   Bangalore  2008-04-28        MS Dhoni
#
#                                          venue  neutral_venue  \
# 0                        M Chinnaswamy Stadium              0
# 1   Punjab Cricket Association Stadium, Mohali              0
# 7              MA Chidambaram Stadium, Chepauk              0
# 9   Punjab Cricket Association Stadium, Mohali              0
# 14                       M Chinnaswamy Stadium              0
#
#                           team1                  team2  \
# 0   Royal Challengers Bangalore  Kolkata Knight Riders
# 1               Kings XI Punjab    Chennai Super Kings
# 7           Chennai Super Kings         Mumbai Indians
# 9               Kings XI Punjab         Mumbai Indians
# ...

# %%
plt.figure(figsize = (5,7))
plt.hist(bat_first["result_margin"])
plt.title("Distribution of runs")
plt.xlabel("Runs")
plt.show()

# %%
ipl["toss_winner"].value_counts()[:3]
# Out:
# Mumbai Indians           106
# Kolkata Knight Riders     98
# Chennai Super Kings       97
# Name: toss_winner, dtype: int64

# %%
ipl["toss_winner"].value_counts().keys()[:3]
# Out:
# Index(['Mumbai Indians', 'Kolkata Knight Riders', 'Chennai Super Kings'], dtype='object')

# %%
plt.figure(figsize=(5,5))
plt.bar(list(ipl["toss_winner"].value_counts().keys()[:3]),list(ipl["toss_winner"].value_counts()[:3]),color = ("blue","purple","yellow"))
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.pie(list(bat_first["winner"].value_counts()),labels = list(bat_first["winner"].value_counts().keys()),autopct = '%0.1f%%')
plt.show()

# %%
bat_second = ipl[ipl["result"] == "wickets"]

# %%
bat_second
# Out:
#           id       city        date player_of_match  \
# 2     335984      Delhi  2008-04-19     MF Maharoof
# 3     335985     Mumbai  2008-04-20      MV Boucher
# 4     335986    Kolkata  2008-04-20       DJ Hussey
# 5     335987     Jaipur  2008-04-21       SR Watson
# 6     335988  Hyderabad  2008-04-22        V Sehwag
# ..       ...        ...         ...             ...
# 808  1216544      Dubai  2020-10-25      RD Gaikwad
# 809  1216545  Abu Dhabi  2020-09-26    Shubman Gill
# 810  1216546      Dubai  2020-10-20        S Dhawan
# 813  1237178  Abu Dhabi  2020-11-06   KS Williamson
# 815  1237181      Dubai  2020-11-10        TA Boult
#
#                                          venue  neutral_venue  \
# 2                             Feroz Shah Kotla              0
# 3                             Wankhede Stadium              0
# 4                                 Eden Gardens              0
# 5                       Sawai Mansingh Stadium              0
# ...

# %%
bat_second.head()
# Out:
#        id       city        date player_of_match  \
# 2  335984      Delhi  2008-04-19     MF Maharoof
# 3  335985     Mumbai  2008-04-20      MV Boucher
# 4  335986    Kolkata  2008-04-20       DJ Hussey
# 5  335987     Jaipur  2008-04-21       SR Watson
# 6  335988  Hyderabad  2008-04-22        V Sehwag
#
#                                        venue  neutral_venue  \
# 2                           Feroz Shah Kotla              0
# 3                           Wankhede Stadium              0
# 4                               Eden Gardens              0
# 5                     Sawai Mansingh Stadium              0
# 6  Rajiv Gandhi International Stadium, Uppal              0
#
#                    team1                        team2       toss_winner  \
# 2       Delhi Daredevils             Rajasthan Royals  Rajasthan Royals
# 3         Mumbai Indians  Royal Challengers Bangalore    Mumbai Indians
# 4  Kolkata Knight Riders              Deccan Chargers   Deccan Chargers
# ...

# %%
plt.figure(figsize=(7,7))
plt.hist(bat_second["result_margin"],bins=30)
plt.show()

# %%
bat_second["winner"].value_counts().head(3)
# Out:
# Kolkata Knight Riders    57
# Mumbai Indians           56
# Chennai Super Kings      53
# Name: winner, dtype: int64

# %%
bat_second["winner"].value_counts().keys()[:3]
# Out:
# Index(['Kolkata Knight Riders', 'Mumbai Indians', 'Chennai Super Kings'], dtype='object')

# %%
plt.figure(figsize=(7,7))
plt.bar(list(bat_second["winner"].value_counts().keys()[:3]),bat_second["winner"].value_counts().head(3),color=("purple","blue","yellow"))
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.pie(list(bat_second["winner"].value_counts()),labels = list(bat_second["winner"].value_counts().keys()),autopct = '%0.1f%%')
plt.show()

# %%
ipl["city"].value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          65
# Hyderabad          64
# Chennai            57
# Chandigarh         56
# Jaipur             47
# Pune               38
# Abu Dhabi          29
# Dubai              26
# Durban             15
# Bengaluru          15
# Visakhapatnam      13
# Sharjah            12
# Ahmedabad          12
# Centurion          12
# Rajkot             10
# Dharamsala          9
# Indore              9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# East London         3
# Kimberley           3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
np.sum(ipl["toss_winner"]==ipl["winner"])
# Out:
# 418
